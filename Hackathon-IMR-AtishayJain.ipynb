# %% [markdown]
# # INNOMATICS RESEARCH LABS- HACKATHON
# # Internship Test-2
# ## Name: Atishay Jain
# ## Dataset used- https://drive.google.com/file/d/1tjoYJhWd-hDo3PnwXXqKNL7yyB3GOrFs/view?usp=sharing

# %% [markdown]
# # EDA of the dataset

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")

# %%
df=pd.read_csv('data (1).csv')

# %%
df.head()
# Out:
#            x1          x2  y
# 0 -119.366669  115.000000  1
# 1 -101.108044   97.777159  1
# 2 -130.278658  106.767654  1
# 3 -114.703415  101.195477  1
# 4 -119.366669  115.000000  1

# %%
df.tail()
# Out:
#               x1            x2  y
# 2222   98.714112  8.964312e+01  0
# 2223   96.633331  9.100000e+01  0
# 2224   85.673940  1.038393e+02  0
# 2225   78.958862  7.860537e+01  0
# 2226  109.624009  1.000000e+08  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227 entries, 0 to 2226
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      2222 non-null   float64
#  1   x2      2224 non-null   float64
#  2   y       2227 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 52.3 KB

# %%
df.describe()
# Out:
#                 x1            x2            y
# count  2222.000000  2.224000e+03  2227.000000
# mean     -4.818766  8.947626e+04     0.442299
# std      74.939909  2.983323e+06     0.496771
# min    -134.369160 -1.348761e+02     0.000000
# 25%     -71.757030 -8.012983e+01     0.000000
# 50%      -9.836555 -1.046151e+00     0.000000
# 75%      59.813962  6.389086e+01     1.000000
# max     134.508687  1.000000e+08     1.000000

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'y'], dtype='object')

# %%
df.isnull().sum()
# Out:
# x1    5
# x2    3
# y     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df.corr()
# Out:
#           x1        x2         y
# x1  1.000000  0.037288 -0.121299
# x2  0.037288  1.000000 -0.026724
# y  -0.121299 -0.026724  1.000000

# %%
x1_mean=np.mean(df['x1'])
x1_mean
# Out:
# -4.818766123605403

# %%
x2_mean=np.mean(df['x2'])
x2_mean
# Out:
# 89476.25894136279

# %%
df['x1'].fillna(x1_mean,inplace=True)

# %%
df['x2'].fillna(x2_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# x1    0
# x2    0
# y     0
# dtype: int64

# %%
df['x1'].plot()
# Out:
# <AxesSubplot:>

# %%
df['x2'].plot()
# Out:
# <AxesSubplot:>

# %%
df['y'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        plt.plot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.barplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['x1'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['x2'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['y'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'x1'}>,
#         <AxesSubplot:title={'center':'x2'}>],
#        [<AxesSubplot:title={'center':'y'}>, <AxesSubplot:>]], dtype=object)

# %%
df.plot.scatter(x = 'x1', y = 'x2')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
df.plot.scatter(x = 'x1', y = 'x2', c = 'y')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
df.plot.scatter(x = 'x1', y = 'x2', c = 'y', s = 190)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
df.plot.hexbin(x = 'x1', y = 'x2', gridsize = 5, C = 'y')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves
andrews_curves(df, 'y')
# Out:
# <AxesSubplot:>

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
sns.relplot(x = 'x1', y = 'y', data = df)
sns.relplot(x = 'x2', y = 'y', data = df)

# %%
sns.relplot(x = 'x1', y = 'y', kind = 'line', data = df, sort = True)

# %%
sns.relplot(x = 'x1', y = 'y', kind = 'line', data = df, sort = True)

# %%
x = df['x1']
y = df['y']

# %%
sns.jointplot(x,y)
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot(x = 'x1', y= 'y', data = df)

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot:>

# %%
q = df['x2'].quantile(0.98)
# we are removing the top 2% data from the x2 column
data_cleaned = df[df['x2']<q]

# %%
data_cleaned
# Out:
#               x1          x2  y
# 0    -119.366669  115.000000  1
# 1    -101.108044   97.777159  1
# 2    -130.278658  106.767654  1
# 3    -114.703415  101.195477  1
# 4    -119.366669  115.000000  1
# ...          ...         ... ..
# 2221   88.129639  107.514918  0
# 2222   98.714112   89.643117  0
# 2223   96.633331   91.000000  0
# 2224   85.673940  103.839270  0
# 2225   78.958862   78.605371  0
#
# [2181 rows x 3 columns]

# %%
plt.scatter(x='x1',y='y')

# %%
plt.scatter(x='x2',y='x')

# %%
X = df.drop(columns = ['y'])
y = df['y']

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.stripplot(y,X[column])
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.53059331e+00, -2.99805398e-02],
#        [-1.28662090e+00, -2.99863180e-02],
#        [-1.67639972e+00, -2.99833017e-02],
#        ...,
#        [ 1.20916689e+00, -2.99842842e-02],
#        [ 1.11943977e+00, -2.99927501e-02],
#        [ 1.52918859e+00,  3.35197986e+01]])

# %%
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["Features"] = X.columns

#let's check the values
vif
# Out:
#        vif Features
# 0  1.00139       x1
# 1  1.00139       x2

# %% [markdown]
# All the VIF values are less than 5 and are very low. That means no multicollinearity. Now, we can go ahead with fitting our data to the model. Before that, let's split our data in test and training set.

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, test_size= 0.25, random_state = 355)

# %%
log_reg = LogisticRegression()

log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
import pickle
# Writing different model files to file
with open( 'modelForPrediction.sav', 'wb') as f:
    pickle.dump(log_reg,f)
    
with open('sandardScalar.sav', 'wb') as f:
    pickle.dump(scalar,f)

# %%
y_pred = log_reg.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.5655296229802513

# %%
# Confusion Matrix
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[244,  61],
#        [181,  71]], dtype=int64)

# %%
true_positive = conf_mat[0][0]
false_positive = conf_mat[0][1]
false_negative = conf_mat[1][0]
true_negative = conf_mat[1][1]

# %%
# Breaking down the formula for Accuracy
Accuracy = (true_positive + true_negative) / (true_positive +false_positive + false_negative + true_negative)
Accuracy
# Out:
# 0.5655296229802513

# %%
# Precison
Precision = true_positive/(true_positive+false_positive)
Precision
# Out:
# 0.8

# %%
# Recall
Recall = true_positive/(true_positive+false_negative)
Recall
# Out:
# 0.5741176470588235

# %%
# F1 Score
F1_Score = 2*(Recall * Precision) / (Recall + Precision)
F1_Score
# Out:
# 0.6684931506849315

# %%
# Area Under Curve
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.5408730158730158

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# What is the significance of Roc curve and AUC?¶
# In real life, we create various models using different algorithms that we can use for classification purpose. We use AUC to determine which model is the best one to use for a given dataset. Suppose we have created Logistic regression, SVM as well as a clustering model for classification purpose. We will calculate AUC for all the models seperately. The model with highest AUC value will be the best model to use.
#
# Advantages of Logisitic Regression
# It is very simple and easy to implement.
# The output is more informative than other classification algorithms
# It expresses the relationship between independent and dependent variables
# Very effective with linearly seperable data
# Disadvantages of Logisitic Regression
# Not effective with data which are not linearly seperable
# Not as powerful as other classification models
# Multiclass classifications are much easier to do with other algorithms than logisitic regression
# It can only predict categorical outcomes

# %% [markdown]
# # Decision Tree

# %%
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from six import StringIO 
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
#let's first visualize the tree on the data without doing any pre processing
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
feature_name=list(X.columns)
class_name = list(y_train.unique())
feature_name
# Out:
# ['x1', 'x2']

# %%
# create a dot_file which stores the tree structure
dot_data = export_graphviz(clf,feature_names = feature_name,rounded = True,filled = True)
# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  
graph.write_png("myTree.png")
# Show graph
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-75-38f9d90dc854> in <module>
#       3 # Draw graph
#       4 graph = pydotplus.graph_from_dot_data(dot_data)
# ----> 5 graph.write_png("myTree.png")
#       6 # Show graph
#       7 Image(graph.create_png())
#
# ~\anaconda3_new\lib\site-packages\pydotplus\graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# ~\anaconda3_new\lib\site-packages\pydotplus\graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# ~\anaconda3_new\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %%
clf.score(x_train,y_train)
# Out:
# 1.0

# %%
py_pred = clf.predict(x_test)

# %%
# accuracy of our classification tree
clf.score(x_test,y_test)
# Out:
# 0.926391382405745

# %%
scalar = StandardScaler()

x_transform = scalar.fit_transform(X)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_transform,y,test_size = 0.30, random_state= 355)

# %%
from sklearn.decomposition import PCA
import numpy as np
pca = PCA()
principalComponents = pca.fit_transform(x_transform)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# # hyperparameter tuning

# %%
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter' : ['best', 'random']
    
}

# %%
grid_search = GridSearchCV(estimator=clf,
                     param_grid=grid_param,
                     cv=5,
                    n_jobs =-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 32),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'entropy', 'max_depth': 28, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}

# %%
grid_search.best_score_
# Out:
# 0.9544315277434249

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth =24, min_samples_leaf= 1, min_samples_split= 2, splitter ='random')
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=24, splitter='random')

# %%
clf.score(x_test,y_test)
# Out:
# 0.9282511210762332

# %%
feature_name=list(X.columns)
class_name = list(y_train.unique())
# create a dot_file which stores the tree structure
dot_data = export_graphviz(clf,rounded = True,filled = True)
# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  
#graph.write_png("tree.png")
# Show graph
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-91-4223b198f735> in <module>
#       7 #graph.write_png("tree.png")
#       8 # Show graph
# ----> 9 Image(graph.create_png())
#
# ~\anaconda3_new\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# ~\anaconda3_new\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %% [markdown]
# # KNN

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
#Let's start with importing necessary libraries
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import KFold
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\atish\anaconda3_new\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot:>

# %%
# let's fit the data into kNN model and see how well it performs:
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_train,y_train)
# Out:
# 0.7227214377406932

# %%
print("The accuracy score is : ", accuracy_score(y_test,y_pred))
# Out:
# The accuracy score is :  0.5007473841554559

# %%
param_grid = { 'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'leaf_size' : [18,20,25,27,30,32,34],
               'n_neighbors' : [3,5,7,9,10,11,12,13]
              }

# %%
gridsearch = GridSearchCV(knn, param_grid,verbose=3)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.612, total=   0.1s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.588, total=   0.0s
# ...
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.547, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.571, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.548, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.612, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.534, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.593, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.587, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.585, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.595, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.579, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.593, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.595, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.582, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.603, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.619, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.609, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.569, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.590, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.587, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.576, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.612, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.606, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.599, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.572, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.563, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.615, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.577, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.588, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.547, total=   0.0s
# [Parallel(n_jobs=1)]: Done 840 out of 840 | elapsed:   16.6s finished
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [18, 20, 25, 27, 30, 32, 34],
#                          'n_neighbors': [3, 5, 7, 9, 10, 11, 12, 13]},
#              verbose=3)

# %%
# let's see the  best parameters according to gridsearch
gridsearch.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 18, 'n_neighbors': 9}

# %%
# we will use the best parameters in our k-NN algorithm and check if accuracy is increasing.
knn = KNeighborsClassifier(algorithm = 'ball_tree', leaf_size =18, n_neighbors =11)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=18, n_neighbors=11)

# %%
knn.score(x_train,y_train)
# Out:
# 0.6790757381258024

# %%
#k-fold cross validation 
kfold = KFold(n_splits=12,random_state= 42)
kfold.get_n_splits(X_scaled)
# Out:
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# 12

# %%
from statistics import mean
knn = KNeighborsClassifier(algorithm = 'ball_tree', leaf_size =18, n_neighbors =11)
cnt =0
count=[]
train_score =[]
test_score = []

for train_index,test_index in kfold.split(X_scaled):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index] # our scaled data is an array so it can work on x[value]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index] # y is a dataframe so we have to use "iloc" to retreive data
    knn.fit(X_train,y_train)
    train_score_ = knn.score(X_train,y_train)
    test_score_ =  knn.score(X_test,y_test)
    cnt+=1
    count.append(cnt)
    train_score.append(train_score_)
    test_score.append(test_score_)
    
    print("for k = ", cnt)
    print("train_score is :  ", train_score_, "and test score is :  ", test_score_)
print("************************************************")
print("************************************************")
print("Average train score is :  ", mean(train_score))
print("Average test score is :  ", mean(test_score))
# Out:
# for k =  1
# train_score is :   0.6697697207251347 and test score is :   0.3225806451612903
# for k =  2
# train_score is :   0.6849583537481627 and test score is :   0.12903225806451613
# for k =  3
# train_score is :   0.6712395884370407 and test score is :   0.25268817204301075
# for k =  4
# train_score is :   0.6878980891719745 and test score is :   0.21505376344086022
# for k =  5
# train_score is :   0.6756491915727585 and test score is :   0.26344086021505375
# for k =  6
# train_score is :   0.6501714845663891 and test score is :   0.6129032258064516
# for k =  7
# train_score is :   0.6496815286624203 and test score is :   0.553763440860215
# for k =  8
# train_score is :   0.6611165523996082 and test score is :   0.4864864864864865
# for k =  9
# train_score is :   0.6581782566111655 and test score is :   0.6702702702702703
# for k =  10
# train_score is :   0.6674828599412341 and test score is :   0.42162162162162165
# for k =  11
# train_score is :   0.6474045053868757 and test score is :   0.5945945945945946
# for k =  12
# train_score is :   0.6640548481880509 and test score is :   0.4918918918918919
# ************************************************
# ************************************************
# Average train score is :   0.6656337482842346
# Average test score is :   0.4178606025380219

# %%
# let's plot the test_accuracy with the value of k in k-fold

plt.plot(count,test_score)
plt.xlabel('Value of K for k-fold')
plt.ylabel('test accuracy')
plt.xticks(np.arange(0, 12, 1)) 
plt.yticks(np.arange(0.65, 1, 0.05))
# Out:
# ([<matplotlib.axis.YTick at 0x1b727dbd400>,
#   <matplotlib.axis.YTick at 0x1b727240940>,
#   <matplotlib.axis.YTick at 0x1b7274e6790>,
#   <matplotlib.axis.YTick at 0x1b7273a0e50>,
#   <matplotlib.axis.YTick at 0x1b7273bbbb0>,
#   <matplotlib.axis.YTick at 0x1b7273bba90>,
#   <matplotlib.axis.YTick at 0x1b7273bb460>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # SVM

# %%
df
# Out:
#               x1            x2  y
# 0    -119.366669  1.150000e+02  1
# 1    -101.108044  9.777716e+01  1
# 2    -130.278658  1.067677e+02  1
# 3    -114.703415  1.011955e+02  1
# 4    -119.366669  1.150000e+02  1
# ...          ...           ... ..
# 2222   98.714112  8.964312e+01  0
# 2223   96.633331  9.100000e+01  0
# 2224   85.673940  1.038393e+02  0
# 2225   78.958862  7.860537e+01  0
# 2226  109.624009  1.000000e+08  0
#
# [2227 rows x 3 columns]

# %%
x=df.drop(['y'],axis=1)
y=df['y']
columns=x.columns

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.svm import SVR
svr= SVR(C=10)

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(C=10)

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,50,100,500],'gamma':[1,0.5,0.1,0.01,0.001] }
grid= GridSearchCV(SVR(),param_grid, verbose=3)

# %%
grid.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ........................ C=0.1, gamma=1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ........................ C=0.1, gamma=1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ........................ C=0.1, gamma=1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ........................ C=0.1, gamma=1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ........................ C=0.1, gamma=1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.5 ................................................
# [CV] ...................... C=0.1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.5 ................................................
# [CV] ...................... C=0.1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.5 ................................................
# [CV] ...................... C=0.1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.5 ................................................
# [CV] ...................... C=0.1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.5 ................................................
# [CV] ...................... C=0.1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...................... C=0.1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...................... C=0.1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...................... C=0.1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...................... C=0.1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...................... C=0.1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..................... C=0.1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..................... C=0.1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..................... C=0.1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..................... C=0.1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..................... C=0.1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................... C=0.1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................... C=0.1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................... C=0.1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................... C=0.1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................... C=0.1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] .......................... C=1, gamma=1, score=nan, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] .......................... C=1, gamma=1, score=nan, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] .......................... C=1, gamma=1, score=nan, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] .......................... C=1, gamma=1, score=nan, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] .......................... C=1, gamma=1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.5 ..................................................
# [CV] ........................ C=1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=1, gamma=0.5 ..................................................
# [CV] ........................ C=1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=1, gamma=0.5 ..................................................
# [CV] ........................ C=1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=1, gamma=0.5 ..................................................
# [CV] ........................ C=1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=1, gamma=0.5 ..................................................
# [CV] ........................ C=1, gamma=0.5, score=nan, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ........................ C=1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ........................ C=1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ........................ C=1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ........................ C=1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ........................ C=1, gamma=0.1, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] ......................... C=10, gamma=1, score=nan, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] ......................... C=10, gamma=1, score=nan, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] ......................... C=10, gamma=1, score=nan, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
# ...
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ -3.77981505 -56.1488394   87.6333313  ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\svm\_base.py", line 160, in fit
#     X, y = self._validate_data(X, y, dtype=np.float64,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 795, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "C:\Users\atish\anaconda3_new\lib\site-packages\sklearn\utils\validation.py", line 619, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  90.6333313  -58.3666687
#   81.1970346 ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.3s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-874621f0c0ab> in <module>
# ----> 1 grid.fit(train_x,train_y)
#
# ~\anaconda3_new\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3_new\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     763             refit_start_time = time.time()
#     764             if y is not None:
# --> 765                 self.best_estimator_.fit(X, y, **fit_params)
#     766             else:
#     767                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3_new\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     158             check_consistent_length(X, y)
#     159         else:
# --> 160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
#     162                                        accept_large_sparse=False)
#
# ~\anaconda3_new\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3_new\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3_new\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3_new\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3_new\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     617             # If input is 1D raise error
#     618             if array.ndim == 1:
# --> 619                 raise ValueError(
#     620                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     621                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 45.39929564  24.95997901  43.20927901 ...  20.76638934  71.68810164
#  -32.59751751].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
grid.best_estimator_
# Out:
# SVR(C=0.1, gamma=1)

# %%
svr_new=SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=1,
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# # LOGISTIC REGRESSION

# %% [markdown]
# ### Advantages :
# Easy, fast and simple classification method.
# θ parameters explains the direction and intensity of significance of independent variables over the dependent variable.
# Can be used for multiclass classifications also.
# #### Loss function is always convex.
# ### Disadvantages :
# Cannot be applied on non-linear classification problems.
# Proper selection of features is required.
# Good signal to noise ratio is expected.
# Colinearity and outliers tampers the accuracy of LR model.
# ### Hyperparameters :
# Logistic regression hyperparameters are similar to that of linear regression. Learning rate(α) and Regularization parameter(λ) have to be tuned properly to achieve high accuracy.

# %% [markdown]
# # KNN

# %% [markdown]
# ### Logistic Regression vs KNN :
# KNN is a non-parametric model, where LR is a parametric model.
# KNN is comparatively slower than Logistic Regression.
# KNN supports non-linear solutions where LR supports only linear solutions.
# LR can derive confidence level (about its prediction), whereas KNN can only output the labels.

# %% [markdown]
# ### Loss function :
# There is no training involved in KNN. During testing, k neighbors with minimum distance, will take part in classification /regression.
# ### Advantages :
# Easy and simple machine learning model.
# Few hyperparameters to tune.
# ### Disadvantages :
# k should be wisely selected.
# Large computation cost during runtime if sample size is large.
# Proper scaling should be provided for fair treatment among features.
# ### Hyperparameters :
# KNN mainly involves two hyperparameters, K value & distance function.
# ### K value : how many neighbors to participate in the KNN algorithm. k should be tuned based on the validation error.
# distance function : Euclidean distance is the most used similarity function. Manhattan distance, Hamming Distance, Minkowski distance are different alternatives.

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ### Advantages :
# No preprocessing needed on data.
# No assumptions on distribution of data.
# Handles colinearity efficiently.
# Decision trees can provide understandable explanation over the prediction.
# ### Disadvantages :
# Chances for overfitting the model if we keep on building the tree to achieve high purity. decision tree pruning can be used to solve this issue.
# Prone to outliers.
# Tree may grow to be very complex while training complicated datasets.
# Looses valuable information while handling continuous variables.
# ### Hyperparameters :
# Decision tree includes many hyperparameters and I will list a few among them.
# criterion : which cost function for selecting the next tree node. Mostly used ones are gini/entropy.
# max depth : it is the maximum allowed depth of the decision tree.
# minimum samples split : It is the minimum nodes required to split an internal node.
# minimum samples leaf : minimum samples that are required to be at the leaf node.
